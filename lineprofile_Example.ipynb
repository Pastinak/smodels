# %%
from line_profiler import LineProfiler
from Example_profile import main
from smodels.theory.particle import Particle

# %%
profiler = LineProfiler()
profiler.add_function(main)
profiler.add_function(Particle.__cmp__)
profiler.enable_by_count()
result = main()
profiler.print_stats()
# Out:
# INFO in databaseObj.loadBinaryFile() in 177: loading binary db file /home/lessa/smodels/smodels-database/db31.pcl format version 210
#  Decomposition Results:
# 	  Total number of topologies: 37
# 	  Total number of elements = 3439
# INFO in databaseObj.loadBinaryFile() in 184: Loaded database from /home/lessa/smodels/smodels-database/db31.pcl in 4.1 secs.
# The largest r-value (theory/upper limit ratio) is  1.2039296443268401
# Timer unit: 1e-06 s
#
# Total time: 96.0142 s
# File: /home/lessa/smodels/Example_profile.py
# Function: main at line 28
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     28                                           def main():
#     29                                               """
#     30                                               Main program. Displays basic use case.
#     31                                               """
#     32         1          9.0      9.0      0.0      t0 = time.time()
#     33                                               #Define your model (list of rEven and rOdd particles)
#     34         1          5.0      5.0      0.0      runtime.modelFile = 'smodels.share.models.mssm'
#     35
#     36                                               # Path to input file (either a SLHA or LHE file)
#     37                                           #     lhefile = 'inputFiles/lhe/gluino_squarks.lhe'
#     38         1          3.0      3.0      0.0      slhafile = 'inputFiles/slha/lightEWinos.slha'
#     39                                               #Define your model
#     40         1     132670.0 132670.0      0.1      model = Model(BSMparticles=BSMList, SMparticles=SMList)
#     41                                           #    model.updateParticles(inputFile=lhefile)
#     42         1    1115060.0 1115060.0      1.2      model.updateParticles(inputFile=slhafile)
#     43
#     44                                               # Set main options for decomposition
#     45         1         23.0     23.0      0.0      sigmacut = 0.2*fb
#     46         1          6.0      6.0      0.0      mingap = 5.*GeV
#     47
#     48                                               # Decompose model
#     49         1   38632026.0 38632026.0     40.2      toplist = decomposer.decompose(model, sigmacut, doCompress=True, doInvisible=True, minmassgap=mingap)
#     50
#     51                                               # Access basic information from decomposition, using the topology list and topology objects:
#     52         1        104.0    104.0      0.0      print("\n Decomposition Results: " )
#     53         1         31.0     31.0      0.0      print("\t  Total number of topologies: %i " %len(toplist) )
#     54         1         23.0     23.0      0.0      nel = sum([len(top.elementList) for top in toplist])
#     55         1         25.0     25.0      0.0      print("\t  Total number of elements = %i " %nel )
#     56                                               #Print information about the m-th topology:
#     57         1          1.0      1.0      0.0      m = 2
#     58         1          2.0      2.0      0.0      if len(toplist) > m:
#     59         1          3.0      3.0      0.0          top = toplist[m]
#     60                                           #        print( "\t\t %i-th topology  = " %m,top,"with total cross section =",top.getTotalWeight() )
#     61                                                   #Print information about the n-th element in the m-th topology:
#     62         1          1.0      1.0      0.0          n = 0
#     63         1          1.0      1.0      0.0          el = top.elementList[n]
#     64                                           #        print( "\t\t %i-th element from %i-th topology  = " %(n,m),el, end="" )
#     65                                           #        print( "\n\t\t\twith final states =",el.getFinalStates(),"\n\t\t\twith cross section =",el.weight,"\n\t\t\tand masses = ",el.mass )
#     66
#     67         1    4190496.0 4190496.0      4.4      database = Database("./smodels-database")
#     68
#     69                                               # Load the experimental results to be used.
#     70                                               # In this case, all results are employed.
#     71         1      11452.0  11452.0      0.0      listOfExpRes = database.getExpResults()
#     72
#     73                                               # Print basic information about the results loaded.
#     74                                               # Count the number of loaded UL and EM experimental results:
#     75         1          3.0      3.0      0.0      nUL, nEM = 0, 0
#     76        77         86.0      1.1      0.0      for exp in listOfExpRes:
#     77        76        122.0      1.6      0.0          expType = exp.datasets[0].dataInfo.dataType
#     78        76         92.0      1.2      0.0          if expType == 'upperLimit':
#     79        55         62.0      1.1      0.0              nUL += 1
#     80        21         26.0      1.2      0.0          elif  expType == 'efficiencyMap':
#     81        21         22.0      1.0      0.0              nEM += 1
#     82                                           #    print("\n Loaded Database with %i UL results and %i EM results " %(nUL,nEM) )
#     83
#     84
#     85                                               # Compute the theory predictions for each experimental result and print them:
#     86                                           #    print("\n Theory Predictions and Constraints:")
#     87         1          1.0      1.0      0.0      rmax = 0.
#     88         1          1.0      1.0      0.0      bestResult = None
#     89        77        145.0      1.9      0.0      for expResult in listOfExpRes:
#     90        76   35605006.0 468486.9     37.1          predictions = theoryPredictionsFor(expResult, toplist, combinedResults=False, marginalize=False)
#     91        76        289.0      3.8      0.0          if not predictions: continue # Skip if there are no constraints from this result
#     92                                           #        print('\n %s ' %expResult.globalInfo.id)
#     93        73        739.0     10.1      0.0          for theoryPrediction in predictions:
#     94        42         72.0      1.7      0.0              dataset = theoryPrediction.dataset
#     95        42        174.0      4.1      0.0              datasetID = theoryPrediction.dataId()
#     96        42         68.0      1.6      0.0              mass = theoryPrediction.mass
#     97        42        329.0      7.8      0.0              txnames = [str(txname) for txname in theoryPrediction.txnames]
#     98        42         72.0      1.7      0.0              PIDs =  theoryPrediction.PIDs
#     99                                           #            print("------------------------" )
#    100                                           #            print("Dataset = ",datasetID )   #Analysis name
#    101                                           #            print("TxNames = ",txnames )
#    102                                           #            print("Prediction Mass = ",mass )   #Value for average cluster mass (average mass of the elements in cluster)
#    103                                           #            print("Prediction PIDs = ",PIDs )   #Value for average cluster mass (average mass of the elements in cluster)
#    104                                           #            print("Theory Prediction = ",theoryPrediction.xsection )  #Signal cross section
#    105                                           #            print("Condition Violation = ",theoryPrediction.conditions ) #Condition violation values
#    106
#    107                                                       # Get the corresponding upper limit:
#    108                                           #            print("UL for theory prediction = ",theoryPrediction.upperLimit )
#    109
#    110                                                       # Compute the r-value
#    111        42       3868.0     92.1      0.0              r = theoryPrediction.getRValue()
#    112                                           #            print("r = ",r )
#    113                                                       #Compute likelihhod and chi^2 for EM-type results:
#    114        42        174.0      4.1      0.0              if dataset.getType() == 'efficiencyMap':
#    115         9      84353.0   9372.6      0.1                  theoryPrediction.computeStatistics()
#    116                                           #                print('Chi2, likelihood=', theoryPrediction.chi2, theoryPrediction.likelihood )
#    117        42         82.0      2.0      0.0              if r > rmax:
#    118         5          7.0      1.4      0.0                  rmax = r
#    119         5         20.0      4.0      0.0                  bestResult = expResult.globalInfo.id
#    120
#    121                                               # Print the most constraining experimental result
#    122         1        127.0    127.0      0.0      print("\nThe largest r-value (theory/upper limit ratio) is ",rmax )
#    123                                           #    if rmax > 1.:
#    124                                           #        print("(The input model is likely excluded by %s)" %bestResult )
#    125                                           #    else:
#    126                                           #        print("(The input model is not excluded by the simplified model results)" )
#    127
#    128                                               #Find out missing topologies for sqrts=8*TeV:
#    129         1   16236269.0 16236269.0     16.9      uncovered = coverage.Uncovered(toplist,sigmacut,sqrts=8.*TeV)
#    130                                               #Print uncovered cross-sections:
#    131                                           #    print("\nTotal missing topology cross section (fb): %10.3E\n" %(uncovered.missingTopos.getTotalXsec()))
#    132                                           #    print("Total cross section where we are outside the mass grid (fb): %10.3E\n" %(uncovered.outsideGrid.getTotalXsec()))
#    133                                           #    print("Total cross section with longlived decays (fb): %10.3E\n" %(uncovered.longLived.getTotalXsec()))
#    134                                           #    print("Total cross section with displaced decays (fb): %10.3E\n" %(uncovered.displaced.getTotalXsec()))
#    135                                           #    print("Total cross section with MET decays (fb): %10.3E\n" %(uncovered.MET.getTotalXsec()))
#    136
#    137
#    138                                               #Print some of the missing topologies:
#    139                                           #    if uncovered.missingTopos.generalElements:
#    140                                           #        print('Missing topologies (up to 3):' )
#    141                                           #        for genEl in sorted(uncovered.missingTopos.generalElements, key=lambda x: x.missingX, reverse=True)[:3]:
#    142                                           #            print('Element:', str(genEl._outputDescription))
#    143                                           #            print('\tcross-section (fb):', genEl.missingX)
#    144                                           #    else:
#    145                                           #        print("No missing topologies found\n")
#    146
#    147                                               #Print elements with displaced decays:
#    148                                           #    if uncovered.displaced.generalElements:
#    149                                           #        print('\nElements with displaced vertices (up to 2):' )
#    150                                           #        for genEl in sorted(uncovered.displaced.generalElements, key=lambda x: x.missingX, reverse=True)[:2]:
#    151                                           #            print('Element:', str(genEl._outputDescription))
#    152                                           #            print('\tcross-section (fb):', genEl.missingX)
#    153                                           #    else:
#    154                                           #        print("\nNo displaced decays")
#    155
#    156         1          4.0      4.0      0.0      return time.time()-t0
#
# Total time: 35.3738 s
# File: /home/lessa/smodels/smodels/theory/particle.py
# Function: __cmp__ at line 45
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     45                                               def __cmp__(self,other):
#     46                                                   """
#     47                                                   Compares particle with other.
#     48                                                   The comparison is based on the particle properties.
#     49                                                   If the particles differ they are sorted according to their label.
#     50                                                   If in addition the particles differ, but have the same label, they
#     51                                                   are sorted according to their properties.
#     52
#     53                                                   :param other:  particle to be compared (Particle object)
#     54
#     55                                                   :return: -1 if self.label < other.label, 0 if self == other, +1, if self.label > other.label.
#     56                                                   """
#     57
#     58   4596098    2856448.0      0.6      8.1          if not isinstance(other,(MultiParticle,Particle)):
#     59                                                       return +1
#     60
#     61                                                   #First check if we have already compared to this object
#     62   4596098    1992924.0      0.4      5.6          idOther = id(other)
#     63   4596098    1834822.0      0.4      5.2          idSelf = id(self)
#     64   4596098    9764712.0      2.1     27.6          if idOther in self._equals or idSelf in other._equals:  #Objects were already compared and are equal
#     65    821820     286003.0      0.3      0.8              return 0
#     66   3774278    7521974.0      2.0     21.3          elif idOther in self._differs or -idSelf in other._differs: #Objects were already compared and differ.
#     67   2015068     720173.0      0.4      2.0              return 1
#     68   1759210    3083710.0      1.8      8.7          elif -idOther in self._differs or idSelf in other._differs:
#     69   1646916     593109.0      0.4      1.7              return -1
#     70                                                   else:
#     71    112294    6080797.0     54.2     17.2              cmpProp = self.cmpProperties(other) #Objects have not been compared yet.
#     72    112294      92108.0      0.8      0.3              if cmpProp == 0:
#     73     83691     220732.0      2.6      0.6                  if not self._static:
#     74       500        820.0      1.6      0.0                      self._equals.add(idOther)
#     75     83691     156185.0      1.9      0.4                  if not other._static:
#     76       209        114.0      0.5      0.0                      other._equals.add(idSelf)
#     77     83691      34215.0      0.4      0.1                  return 0
#     78                                                       else:
#     79     28603      64991.0      2.3      0.2                  if not self._static:
#     80       999       2217.0      2.2      0.0                      self._differs.add(idOther*cmpProp)
#     81     28603      53711.0      1.9      0.2                  if not other._static:
#     82       949       1304.0      1.4      0.0                      other._differs.add(-idSelf*cmpProp)
#     83     28603      12757.0      0.4      0.0                  return cmpProp
