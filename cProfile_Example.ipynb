# %%
import cProfile
from Example_profile import main

# %%
profile = cProfile.Profile()
profile.enable()
result = main()
profile.disable()
profile.print_stats(sort='cumtime')
# Out:
# INFO in databaseObj.loadBinaryFile() in 177: loading binary db file /home/lessa/smodels/smodels-database/db31.pcl format version 210
#  Decomposition Results:
# 	  Total number of topologies: 37
# 	  Total number of elements = 3439
# INFO in databaseObj.loadBinaryFile() in 184: Loaded database from /home/lessa/smodels/smodels-database/db31.pcl in 0.6 secs.
# The largest r-value (theory/upper limit ratio) is  1.2039296443268401
#          77028752 function calls (74981793 primitive calls) in 41.114 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000   41.114   20.557 interactiveshell.py:3230(run_code)
#         2    0.000    0.000   41.114   20.557 {built-in method builtins.exec}
#         1    0.019    0.019   41.114   41.114 <ipython-input-2-45f3eefbec76>:3(<module>)
#         1    0.002    0.002   41.094   41.094 Example_profile.py:28(main)
# ...

# %%
print('Done in %1.2f' %result)
# Out:
# Done in 41.09
